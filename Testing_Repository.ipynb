# %% [markdown]
# ##IMPORTANT NOTICE
#
# This document contains all of the code necessary to reproduce the results in the Test Plan and Results Documentation. It is not stand alone. In order to run the code, either past the desired cells from this document into the main code file or copy the functions from that file here.
#
# This code does not need to be run, it is merely included for the sake of completeness

# %%
#portfolio

stock_lst = ['HD','UNH']
long_short_put_call_lst = ['Long','Short']
units_lst = [475,619]

# %%
#sample means
mewbar_wind_port, mewbar_wind_HD, mewbar_wind_UNH = get_mewbar_window(years=5,percent_returns=port_percent_returns,back=252*10),get_mewbar_window(years=5,percent_returns=stock_percent_returns[0],back=252*10),get_mewbar_window(years=5,percent_returns=stock_percent_returns[1],back=252*10)
mewbar_expon_port, mewbar_expon_HD, mewbar_expon_UNH = get_mewbar_expon(lamd=.9989,percent_returns=port_percent_returns,back=252*10),get_mewbar_expon(lamd=.9989,percent_returns=stock_percent_returns[0],back=252*10),get_mewbar_expon(lamd=.9989,percent_returns=stock_percent_returns[1],back=252*10)

dates = port_percent_returns.index[len(port_percent_returns)-len(mewbar_wind_port):]
fig,ax = plt.subplots(nrows=1,ncols=2,figsize=(10,4),sharey=True)
for i,portfolio,HD,UNH,weighting_type in zip([0,1],[mewbar_wind_port,mewbar_expon_port],[mewbar_wind_HD,mewbar_expon_HD],[mewbar_wind_UNH,mewbar_expon_UNH],['Windowing','Exponential']):
  ax[i].xaxis.set_major_locator(MaxNLocator(nbins=6))
  ax[i].plot(dates,portfolio,label='Portfolio',linewidth=.5)
  ax[i].plot(dates,HD,label='HD',linewidth=.5)
  ax[i].plot(dates,UNH,label='UNH',linewidth=.5)
  ax[i].legend(); ax[i].set_title(f'{weighting_type} Mean Weighting')
for axs in ax:
    axs.tick_params(left=True, labelleft=True)
plt.show()

# %%
#sample standard deviaition
mewbar_wind_port, mewbar_wind_HD, mewbar_wind_UNH = get_sdbar_window(years=5,percent_returns=port_percent_returns,back=252*10),get_sdbar_window(years=5,percent_returns=stock_percent_returns[0],back=252*10),get_sdbar_window(years=5,percent_returns=stock_percent_returns[1],back=252*10)
mewbar_expon_port, mewbar_expon_HD, mewbar_expon_UNH = get_sdbar_expon(lamd=.9989,percent_returns=port_percent_returns,back=252*10),get_sdbar_expon(lamd=.9989,percent_returns=stock_percent_returns[0],back=252*10),get_sdbar_expon(lamd=.9989,percent_returns=stock_percent_returns[1],back=252*10)

dates = port_percent_returns.index[len(port_percent_returns)-len(mewbar_wind_port):]
fig,ax = plt.subplots(nrows=1,ncols=2,figsize=(10,4),sharey=True)
for i,portfolio,HD,UNH,weighting_type in zip([0,1],[mewbar_wind_port,mewbar_expon_port],[mewbar_wind_HD,mewbar_expon_HD],[mewbar_wind_UNH,mewbar_expon_UNH],['Windowing','Exponential']):
  ax[i].xaxis.set_major_locator(MaxNLocator(nbins=6))
  ax[i].plot(dates,portfolio,label='Portfolio',linewidth=1)
  ax[i].plot(dates,HD,label='HD',linewidth=1)
  ax[i].plot(dates,UNH,label='UNH',linewidth=1)
  ax[i].legend(); ax[i].set_title(f'{weighting_type} Standard Deviation')
for axs in ax:
    axs.tick_params(left=True, labelleft=True)
plt.show()

# %%
#GBM parameters
[port_wind_GBM_sd, port_wind_GBM_mu], [HD_wind_GBM_sd, HD_wind_GBM_mu], [UNH_wind_GBM_sd, UNH_wind_GBM_mu] = get_gbm(years=5,percent_returns=port_percent_returns,back=252*10),get_gbm(years=5,percent_returns=stock_percent_returns[0],back=252*10),get_gbm(years=5,percent_returns=stock_percent_returns[1],back=252*10)
[port_expon_GBM_sd, port_expon_GBM_mu], [HD_expon_GBM_sd, HD_expon_GBM_mu], [UNH_expon_GBM_sd, UNH_expon_GBM_mu] = get_gbm(lamb=.9989,percent_returns=port_percent_returns,back=252*10),get_gbm(lamb=.9989,percent_returns=stock_percent_returns[0],back=252*10),get_gbm(lamb=.9989,percent_returns=stock_percent_returns[1],back=252*10)

dates = port_percent_returns.index[len(port_percent_returns)-len(port_wind_GBM_sd):]

fig,ax = plt.subplots(nrows=1,ncols=2,figsize=(10,4),sharey=True)
for i,portfolio,HD,UNH,weighting_type in zip([0,1],[port_wind_GBM_mu,port_expon_GBM_mu],[HD_wind_GBM_mu,HD_expon_GBM_mu],[UNH_wind_GBM_mu,UNH_expon_GBM_mu],['Windowing','Exponential']):
  ax[i].xaxis.set_major_locator(MaxNLocator(nbins=6))
  ax[i].plot(dates,portfolio,label='Portfolio',linewidth=.5)
  ax[i].plot(dates,HD,label='HD',linewidth=.5)
  ax[i].plot(dates,UNH,label='UNH',linewidth=.5)
  ax[i].legend(); ax[i].set_title(f'{weighting_type} GBM Mu')
for axs in ax:
    axs.tick_params(left=True, labelleft=True)
plt.show()

fig,ax = plt.subplots(nrows=1,ncols=2,figsize=(10,4),sharey=True)
for i,portfolio,HD,UNH,weighting_type in zip([0,1],[port_wind_GBM_sd,port_expon_GBM_sd],[HD_wind_GBM_sd,HD_expon_GBM_sd],[UNH_wind_GBM_sd,UNH_expon_GBM_sd],['Windowing','Exponential']):
  ax[i].xaxis.set_major_locator(MaxNLocator(nbins=6))
  ax[i].plot(dates,portfolio,label='Portfolio',linewidth=1)
  ax[i].plot(dates,HD,label='HD',linewidth=1)
  ax[i].plot(dates,UNH,label='UNH',linewidth=1)
  ax[i].legend(); ax[i].set_title(f'{weighting_type} GBM Sigma')
for axs in ax:
    axs.tick_params(left=True, labelleft=True)
plt.show()

# %%
#VaR and ES calculation
window_long_VaR = get_VaR(percent_returns=port_percent_returns,years=5,cash=10000,lamb=False)
exponential_long_VaR = get_VaR(percent_returns=port_percent_returns,years=False,cash=10000,lamb=.9989)
window_short_VaR = get_short_VaR(percent_returns=port_percent_returns,years=5,cash=10000,lamb=False)
exponential_short_VaR = get_short_VaR(percent_returns=port_percent_returns,years=False,cash=10000,lamb=.9989)

window_long_ES = get_ES(percent_returns=port_percent_returns,years=5,cash=10000,lamb=False)
exponential_long_ES = get_ES(percent_returns=port_percent_returns,years=False,cash=10000,lamb=.9989)
window_short_ES = get_short_ES(percent_returns=port_percent_returns,years=5,cash=10000,lamb=False)
exponential_short_ES = get_short_ES(percent_returns=port_percent_returns,years=False,cash=10000,lamb=.9989)

monte_carlo_VaR, monte_carlo_ES, monte_carlo_short_VaR, monte_carlo_short_ES  = get_MC_VaR_ES(percent_returns_lst=stock_percent_returns, position_values_lst=position_values,stock_proportions_lst=stock_proportions,cash=10000, positions=long_short_put_call_lst,units=units_lst, sims=10000, years=5,p=.99,back=252*10,lamb=False)

long_historical_VaR,long_historical_ES,short_historical_VaR,short_historical_ES = get_historical_VaR(position_values_lst = position_values,cash=10000,positions=long_short_put_call_lst,years=5,p=.99,back=252*10)

dates = port_percent_returns.index[len(port_percent_returns)-len(window_long_VaR):]
fig,ax = plt.subplots(nrows=1,ncols=4,figsize=(14,3),sharey=True)
for name,i,VaR_lst in zip(['Window','Exponential','Monte Carlo','Historical'],[0,1,2,3],[[window_short_VaR,window_long_VaR],[exponential_short_VaR,exponential_long_VaR],[monte_carlo_short_VaR,monte_carlo_VaR],[short_historical_VaR,long_historical_VaR]]):
  ax[i].xaxis.set_major_locator(MaxNLocator(nbins=5))
  ax[i].plot(dates,VaR_lst[0],label='Short',linewidth=.5)
  ax[i].plot(dates,VaR_lst[1],label="Long",linewidth=.5)
  ax[i].legend(); ax[i].set_title(f'99% {name} VaR')
for axs in ax:
    axs.tick_params(left=True, labelleft=True)
plt.show()

# @title
dates = port_percent_returns.index[len(port_percent_returns)-len(window_long_VaR):]
fig,ax = plt.subplots(nrows=1,ncols=4,figsize=(14,3),sharey=True)
for name,i,VaR_lst in zip(['Window','Exponential','Monte Carlo','Historical'],[0,1,2,3],[[window_short_ES,window_long_ES],[exponential_short_ES,exponential_long_ES],[monte_carlo_short_ES,monte_carlo_ES],[short_historical_ES,long_historical_ES]]):
  ax[i].xaxis.set_major_locator(MaxNLocator(nbins=5))
  ax[i].plot(dates,VaR_lst[0],label='Short',linewidth=.5)
  ax[i].plot(dates,VaR_lst[1],label="Long",linewidth=.5)
  ax[i].legend(); ax[i].set_title(f'97.5% {name} ES')
for axs in ax:
    axs.tick_params(left=True, labelleft=True)
plt.show()

# %%
#VaR backtesting
dates = port_percent_returns.index[len(port_percent_returns)-len(window_long_VaR)+252:]
fig,ax = plt.subplots(nrows=1,ncols=4,figsize=(14,3),sharey=True)
for name,i,VaR_lst in zip(['Window','Exponential','Monte Carlo','Historical'],[0,1,2,3],[[window_short_VaR,window_long_VaR],[exponential_short_VaR,exponential_long_VaR],[monte_carlo_short_VaR,monte_carlo_VaR],[short_historical_VaR,long_historical_VaR]]):
  long_VaR_backtesting, short_VaR_backtesting = get_year_window(long_VaR_ts=VaR_lst[1],short_VaR_ts=VaR_lst[0],position_values_lst=position_values,positions=['Long','Long'],cash=10000)
  ax[i].xaxis.set_major_locator(MaxNLocator(nbins=5))
  ax[i].plot(dates,short_VaR_backtesting,label='Short',linewidth=1)
  ax[i].plot(dates,long_VaR_backtesting,label="Long",linewidth=1)
  ax[i].legend(); ax[i].set_title(f'{name} VaR Backtesting')
for axs in ax:
    axs.tick_params(left=True, labelleft=True)
plt.show()

# %%
#portfolio construction testing
stock_lst = ['AAPL','JNJ','GE']
long_short_put_call_lst_1 = ['Long','Long','Long']; units_lst_1 = [100,150,200]
port_percent_returns_1,stock_percent_returns_1,stock_proportions_1,position_values_1 = get_percent_returns(stocks=stock_lst,positions=long_short_put_call_lst_1,units=units_lst_1,start_date='1985-09-04',end_date='2023-09-26')
monte_carlo_VaR_1, monte_carlo_ES_1, monte_carlo_short_VaR_1, monte_carlo_short_ES_1  = get_MC_VaR_ES(percent_returns_lst=stock_percent_returns_1, position_values_lst=position_values_1,stock_proportions_lst=stock_proportions_1,cash=10000, positions=long_short_put_call_lst_1,units=units_lst_1, sims=10000, years=5,p=.99,back=252*10,lamb=False)

stock_lst = ['AAPL','JNJ','GE']
long_short_put_call_lst_2 = ['Short','Long','Call']; units_lst_2 = [100,150,[300,.4,.5,.005]]
port_percent_returns_2,stock_percent_returns_2,stock_proportions_2,position_values_2 = get_percent_returns(stocks=stock_lst,positions=long_short_put_call_lst_2,units=units_lst_2,start_date='1985-09-04',end_date='2023-09-26')
monte_carlo_VaR_2, monte_carlo_ES_2, monte_carlo_short_VaR_2, monte_carlo_short_ES_2  = get_MC_VaR_ES(percent_returns_lst=stock_percent_returns_2, position_values_lst=position_values_2,stock_proportions_lst=stock_proportions_2,cash=10000, positions=long_short_put_call_lst_2,units=units_lst_2, sims=1000, years=5,p=.99,back=252*10,lamb=False)

stock_lst = ['AAPL','JNJ','GE']
long_short_put_call_lst_3 = ['Call','Put','Put']; units_lst_3 = [[100,.4,1/12,.01],[100,.25,1,.01],[100,.2,1/6,.01]]
port_percent_returns_3,stock_percent_returns_3,stock_proportions_3,position_values_3 = get_percent_returns(stocks=stock_lst,positions=long_short_put_call_lst_3,units=units_lst_3,start_date='1985-09-04',end_date='2023-09-26')
monte_carlo_VaR_3, monte_carlo_ES_3, monte_carlo_short_VaR_3, monte_carlo_short_ES_3  = get_MC_VaR_ES(percent_returns_lst=stock_percent_returns_3, position_values_lst=position_values_3,stock_proportions_lst=stock_proportions_3,cash=10000, positions=long_short_put_call_lst_3,units=units_lst_3, sims=1000, years=5,p=.99,back=252*10,lamb=False)

dates = port_percent_returns_1.index[len(port_percent_returns_1)-len(monte_carlo_VaR_1):]
fig,ax = plt.subplots(nrows=1,ncols=3,figsize=(14,4),sharey=False)
for name,i,VaR_lst in zip(['Long Only','Combination','Pure Options'],[0,1,2],[[monte_carlo_short_VaR_1,monte_carlo_VaR_1],[monte_carlo_short_VaR_2,monte_carlo_VaR_2],[monte_carlo_short_VaR_3,monte_carlo_VaR_3]]):
  ax[i].xaxis.set_major_locator(MaxNLocator(nbins=5))
  ax[i].plot(dates,VaR_lst[0],label='Short',linewidth=.5)
  ax[i].plot(dates,VaR_lst[1],label="Long",linewidth=.5)
  ax[i].legend(); ax[i].set_title(f'99% {name} VaR')
for axs in ax:
    axs.tick_params(left=True, labelleft=True)
plt.show()

fig,ax = plt.subplots(nrows=1,ncols=3,figsize=(14,4),sharey=False)
for name,i,VaR_lst in zip(['Long Only','Combination','Pure Options'],[0,1,2],[[monte_carlo_short_ES_1,monte_carlo_ES_1],[monte_carlo_short_ES_2,monte_carlo_ES_2],[monte_carlo_short_ES_3,monte_carlo_ES_3]]):
  ax[i].xaxis.set_major_locator(MaxNLocator(nbins=5))
  ax[i].plot(dates,VaR_lst[0],label='Short',linewidth=.5)
  ax[i].plot(dates,VaR_lst[1],label="Long",linewidth=.5)
  ax[i].legend(); ax[i].set_title(f'97.5% {name} ES')
for axs in ax:
    axs.tick_params(left=True, labelleft=True)
plt.show()

dates = port_percent_returns.index[len(port_percent_returns)-len(window_long_VaR)+252:]
fig,ax = plt.subplots(nrows=1,ncols=3,figsize=(14,4),sharey=True)
for name,i,VaR_lst,long_short_put_call in zip(['Long Only','Combination','Pure Options'],[0,1,2],[[monte_carlo_short_VaR_1,monte_carlo_VaR_1,position_values_1],[monte_carlo_short_VaR_2,monte_carlo_VaR_2,position_values_2],[monte_carlo_short_VaR_3,monte_carlo_VaR_3,position_values_3]],[['Long','Long','Long'],['Short','Long','Call'],['Call','Put','Put']]):
  long_VaR_backtesting, short_VaR_backtesting = get_year_window(long_VaR_ts=VaR_lst[1],short_VaR_ts=VaR_lst[0],position_values_lst=VaR_lst[2],positions=long_short_put_call,cash=10000)
  ax[i].xaxis.set_major_locator(MaxNLocator(nbins=5))
  ax[i].plot(dates,short_VaR_backtesting,label='Short',linewidth=1)
  ax[i].plot(dates,long_VaR_backtesting,label="Long",linewidth=1)
  ax[i].legend(); ax[i].set_title(f'{name} VaR Backtesting')
for axs in ax:
    axs.tick_params(left=True, labelleft=True)
plt.show()

# %%
#windowing testing
stock_lst = ['AAPL','GE']
long_short_put_call_lst = ['Long','Long']
units_lst = [100,200]

port_percent_returns,stock_percent_returns,stock_proportions,position_values = get_percent_returns(stocks=stock_lst,positions=long_short_put_call_lst,units=units_lst,start_date='1985-09-04',end_date='2023-09-26')

window_long_VaR_1 = get_VaR(percent_returns=port_percent_returns,years=1,cash=10000,lamb=False)
window_short_VaR_1 = get_short_VaR(percent_returns=port_percent_returns,years=1,cash=10000,lamb=False)
window_long_ES_1 = get_ES(percent_returns=port_percent_returns,years=1,cash=10000,lamb=False)
window_short_ES_1 = get_short_ES(percent_returns=port_percent_returns,years=1,cash=10000,lamb=False)

window_long_VaR_2 = get_VaR(percent_returns=port_percent_returns,years=3,cash=10000,lamb=False)
window_short_VaR_2 = get_short_VaR(percent_returns=port_percent_returns,years=3,cash=10000,lamb=False)
window_long_ES_2 = get_ES(percent_returns=port_percent_returns,years=3,cash=10000,lamb=False)
window_short_ES_2 = get_short_ES(percent_returns=port_percent_returns,years=3,cash=10000,lamb=False)

window_long_VaR_3 = get_VaR(percent_returns=port_percent_returns,years=8,cash=10000,lamb=False)
window_short_VaR_3 = get_short_VaR(percent_returns=port_percent_returns,years=8,cash=10000,lamb=False)
window_long_ES_3 = get_ES(percent_returns=port_percent_returns,years=8,cash=10000,lamb=False)
window_short_ES_3 = get_short_ES(percent_returns=port_percent_returns,years=8,cash=10000,lamb=False)

dates = port_percent_returns.index[len(port_percent_returns)-len(window_long_VaR_1):]
fig,ax = plt.subplots(nrows=1,ncols=3,figsize=(14,4),sharey=True)
for name,i,VaR_lst in zip(['1','3','8'],[0,1,2],[[window_short_VaR_1,window_long_VaR_1],[window_short_VaR_2,window_long_VaR_2],[window_short_VaR_3,window_long_VaR_3]]):
  ax[i].xaxis.set_major_locator(MaxNLocator(nbins=5))
  ax[i].plot(dates,VaR_lst[0],label='Short',linewidth=.5)
  ax[i].plot(dates,VaR_lst[1],label="Long",linewidth=.5)
  ax[i].legend(); ax[i].set_title(f'{name} Year Windowing VaR')
for axs in ax:
    axs.tick_params(left=True, labelleft=True)
plt.show()

fig,ax = plt.subplots(nrows=1,ncols=3,figsize=(14,4),sharey=True)
for name,i,VaR_lst in zip(['1','3','8'],[0,1,2],[[window_short_ES_1,window_long_ES_1],[window_short_ES_2,window_long_ES_2],[window_short_ES_3,window_long_ES_3]]):
  ax[i].xaxis.set_major_locator(MaxNLocator(nbins=5))
  ax[i].plot(dates,VaR_lst[0],label='Short',linewidth=.5)
  ax[i].plot(dates,VaR_lst[1],label="Long",linewidth=.5)
  ax[i].legend(); ax[i].set_title(f'{name} Year Windowing ES')
for axs in ax:
    axs.tick_params(left=True, labelleft=True)
plt.show()

dates = port_percent_returns.index[len(port_percent_returns)-len(window_long_VaR_1)+252:]
fig,ax = plt.subplots(nrows=1,ncols=3,figsize=(14,4),sharey=True)
for name,i,VaR_lst in zip(['1','3','8'],[0,1,2],[[window_short_VaR_1,window_long_VaR_1,position_values],[window_short_VaR_2,window_long_VaR_2,position_values],[window_short_VaR_3,window_long_VaR_3,position_values]]):
  long_VaR_backtesting, short_VaR_backtesting = get_year_window(long_VaR_ts=VaR_lst[1],short_VaR_ts=VaR_lst[0],position_values_lst=VaR_lst[2],positions=['Long','Long'],cash=10000)
  ax[i].xaxis.set_major_locator(MaxNLocator(nbins=5))
  ax[i].plot(dates,short_VaR_backtesting,label='Short',linewidth=1)
  ax[i].plot(dates,long_VaR_backtesting,label="Long",linewidth=1)
  ax[i].legend(); ax[i].set_title(f'{name} VaR Backtesting')
for axs in ax:
    axs.tick_params(left=True, labelleft=True)
plt.show()

# %%
#monte carlo simulation size testing

stock_lst = ['JNJ','GE']
long_short_put_call_lst = ['Long','Short']
units_lst = [200,150]

port_percent_returns,stock_percent_returns,stock_proportions,position_values = get_percent_returns(stocks=stock_lst,positions=long_short_put_call_lst,units=units_lst,start_date='1985-09-04',end_date='2023-09-26')

monte_carlo_VaR_1, monte_carlo_ES_1, monte_carlo_short_VaR_1, monte_carlo_short_ES_1  = get_MC_VaR_ES(percent_returns_lst=stock_percent_returns, position_values_lst=position_values,stock_proportions_lst=stock_proportions,cash=10000, positions=long_short_put_call_lst,units=units_lst, sims=100, years=5,p=.99,back=252*10,lamb=False)
monte_carlo_VaR_2, monte_carlo_ES_2, monte_carlo_short_VaR_2, monte_carlo_short_ES_2  = get_MC_VaR_ES(percent_returns_lst=stock_percent_returns, position_values_lst=position_values,stock_proportions_lst=stock_proportions,cash=10000, positions=long_short_put_call_lst,units=units_lst, sims=10000, years=5,p=.99,back=252*10,lamb=False)
monte_carlo_VaR_3, monte_carlo_ES_3, monte_carlo_short_VaR_3, monte_carlo_short_ES_3  = get_MC_VaR_ES(percent_returns_lst=stock_percent_returns, position_values_lst=position_values,stock_proportions_lst=stock_proportions,cash=10000, positions=long_short_put_call_lst,units=units_lst, sims=1000000, years=5,p=.99,back=252*10,lamb=False)

dates = port_percent_returns.index[len(port_percent_returns)-len(monte_carlo_VaR_1):]
fig,ax = plt.subplots(nrows=1,ncols=3,figsize=(14,4),sharey=True)
for name,i,VaR_lst in zip(['100','10000','1000000'],[0,1,2],[[monte_carlo_short_VaR_1,monte_carlo_VaR_1],[monte_carlo_short_VaR_2,monte_carlo_VaR_2],[monte_carlo_short_VaR_3,monte_carlo_VaR_3]]):
  ax[i].xaxis.set_major_locator(MaxNLocator(nbins=5))
  ax[i].plot(dates,VaR_lst[0],label='Short',linewidth=.5)
  ax[i].plot(dates,VaR_lst[1],label="Long",linewidth=.5)
  ax[i].legend(); ax[i].set_title(f'MC VaR with {name} Simulations')
for axs in ax:
    axs.tick_params(left=True, labelleft=True)
plt.show()

fig,ax = plt.subplots(nrows=1,ncols=3,figsize=(14,4),sharey=True)
for name,i,VaR_lst in zip(['100','10000','1000000'],[0,1,2],[[monte_carlo_short_ES_1,monte_carlo_ES_1],[monte_carlo_short_ES_2,monte_carlo_ES_2],[monte_carlo_short_ES_3,monte_carlo_ES_3]]):
  ax[i].xaxis.set_major_locator(MaxNLocator(nbins=5))
  ax[i].plot(dates,VaR_lst[0],label='Short',linewidth=.5)
  ax[i].plot(dates,VaR_lst[1],label="Long",linewidth=.5)
  ax[i].legend(); ax[i].set_title(f'MC ES with {name} Simulations')
for axs in ax:
    axs.tick_params(left=True, labelleft=True)
plt.show()

dates = port_percent_returns.index[len(port_percent_returns)-len(monte_carlo_VaR_1)+252:]
fig,ax = plt.subplots(nrows=1,ncols=3,figsize=(14,4),sharey=True)
for name,i,VaR_lst in zip(['100','10000','1000000'],[0,1,2],[[monte_carlo_short_VaR_1,monte_carlo_VaR_1,position_values],[monte_carlo_short_VaR_2,monte_carlo_VaR_2,position_values],[monte_carlo_short_VaR_3,monte_carlo_VaR_3,position_values]]):
  long_VaR_backtesting, short_VaR_backtesting = get_year_window(long_VaR_ts=VaR_lst[1],short_VaR_ts=VaR_lst[0],position_values_lst=VaR_lst[2],positions=['Long','Short'],cash=10000)
  ax[i].xaxis.set_major_locator(MaxNLocator(nbins=5))
  ax[i].plot(dates,short_VaR_backtesting,label='Short',linewidth=1)
  ax[i].plot(dates,long_VaR_backtesting,label="Long",linewidth=1)
  ax[i].legend(); ax[i].set_title(f'{name} Simulations VaR Backtesting')
for axs in ax:
    axs.tick_params(left=True, labelleft=True)
plt.show()
